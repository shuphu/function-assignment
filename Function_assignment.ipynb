# %%
# Q1.What is the difference between a function and a method in Python?
"""Ans: Function: A function is a block of organized,reusable code that performs a specfic task.
def name(my_name):
  print(f"Hello, my name is {my_name}")
name("Shubham")
Methods: Methods is associated with object or class.It is also a block of code that is called by its name.
class Human:
  def my_name(self):
    return "shubham"
name = Human()
print(name.my_name())"""

#Q2. Explain the concept of function arguments and parameters in Python?
"""Ans:Parameters: Parameters are variable listed within the parenthesis () for the value that will be passed to the function when it's called.
Parameters acts as input in function.
def my_name(name): #name is a parameter.
  print(f"Hello,my name is {name})
my_name("Shubham") #Shubham is a argument.
Arguments:Arguments are actual values that pass in a function when it's called."""

#Q3.What are the different ways to define and call a function in Python?
"""Ans:
1. By using def keywords.
    def fun_name()
    print("hello")
2. Using Lambda function
lambda arguments: expression
sqaure = lambda x: x*x
print(sqaure(5))

calling functins by function name
function_name(arguments)"""

#Q4. What is the purpose of the `return` statement in a Python function?
"""Ans:"return" statement in a python function terminates the execution of the function and give the output.
def add(x,y):
  sum = x+y
  return sum
print(add(2,3))"""

#Q5.What are iterators in Python and how do they differ from iterables?
"""Ans:
Iterables:
Definition: An iterable is any Python object that can be iterated over, meaning you can loop through its elements one by one.
Examples: Lists, tuples, strings, dictionaries, sets, files, and generators are all examples of iterables.
Iterators:
Definition: An iterator is an object that represents a stream of data. It is used to iterate over the elements of an iterable.
my_list = [1, 2, 3, 4, 5]  # my_list is an iterable

# Get an iterator from the list
my_iterator = iter(my_list)

# Iterate through the elements using the iterator
print(next(my_iterator))  # Output: 1
print(next(my_iterator))  # Output: 2
print(next(my_iterator))  # Output: 3
# ... and so on"""

#Q6.Explain the concept of generators in Python and how they are defined?
"""Ans: Generators are special type iterator in a python.Generators are functions that can be paused and resumed, producing a sequence of values one at a time instead of generating the entire sequence at once.
Characteristics of Generators:
1.Generators produce value on demand that makes memory efficent when we dealing with large sequence.
2.Generators use yield instead of return.
def my_geneartors(n):
  for i in range(n):
    yield i * 2
gen = my_generators(5)
print(next(gen))
print(next(gen))
print(next(gen))"""

#Q7.What are the advantages of using generators over regular functions?
"""Ans: There are some advantages of using generators over regular functions:
1.Memory efficiency: Generators produce a values on a demand meaning regular function return all values but generators so memory efficiency increase.
2.Improved Performance
3.Representing Infinite Sequences
4.Readability and Conciseness
5.Pipeline Processing"""

#Q8. What is a lambda function in Python and when is it typically used?
"""Ans:In a python lambda function is a small,anonymous function defined using lambda keyword.We can give any no. of argument but only one expression.
square = lambda x: x*x
print(square(5))"""

#Q9. Explain the purpose and usage of the `map()` function in Python?
"""Ans:The map() function is a built in python function that applies a given function to each item of an iterable(list,tuple,etc.) and returns an iterator of the results.
syntax:
map(function,iterable)
code:
num = [1,2,3,4,5]
square = list(map(lambda x: x*x,num))
print(sqaure)"""

#Q10.What is the difference between `map()`, `reduce()`, and `filter()` functions in Python?
"""Ans:1.The map():
syntax:
map(function,iterable)
code:
num = [1,2,3,4,5]
square = list(map(lambda x: x*x,num))
print(sqaure)
2.The reduce():
syntax:
reduce(function,iterable)
code:
from functools import reduce
num = [1,2,3,4,5]
sum = reduce(lambda x,y: x+y,num)
print(sum)
3.The filter():
syntax:
filter(function,iterable)
code:
num = [1,2,3,4,5]
even = list(filter(lambda x: x%2==0,num))
print(even)"""

# %% [markdown]
# Q11.Using pen & Paper write the internal mechanism for sum operation using  reduce function on this given list:[47,11,42,13];
# ANS:![Assignments reduce function.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# Practical Question and Answer

# %%
#Q1. Write a Python function that takes a list of numbers as input and returns the sum of all even numbers in
#Ans:
numbers = [1,2,3,4,5,6,7,8]
def sum_even_numbers(numbers):
  even_sum = 0
  for num in numbers:
    if num % 2 == 0:
      even_sum = even_sum + num
  return even_sum
print(sum_even_numbers(numbers))

# %%
#Q2. Create a Python function that accepts a string and returns the reverse of that string?
#Ans:
def reverse_string(string):
  reversed_string = string[::-1]
  return reversed_string
print(reverse_string("hello world"))

# %%
#Q3. Implement a Python function that takes a list of integers and returns a new list containing the squares of each number
#Ans:
def square_numbers(numbers):
  squared_numbers = []
  for num in numbers:
    squared_numbers.append(num**2)
  return squared_numbers
print(square_numbers([1,2,3,4,5]))

# %%
#Q4.Write a Python function that checks if a given number is prime or not from 1 to 200.
#Ans:
def is_prime(n):

    if n < 2 or n > 200:
        return False
    if n in (2, 3):
        return True
    if n % 2 == 0 or n % 3 == 0:
        return False

    i = 5
    while i * i <= n:
        if n % i == 0 or n % (i + 2) == 0:
            return False
        i += 6
    return True

# Example usage:
for num in range(1, 201):
    if is_prime(num):
        print(num, "is a prime number.")

# %%
#Q5.Create an iterator class in Python that generates the Fibonacci sequence up to a specified number of terms?
#Ans:
class FibonacciIterator:
    def __init__(self, num_terms):
        self.num_terms = num_terms
        self.current_term = 0
        self.a = 0
        self.b = 1

    def __iter__(self):
        return self

    def __next__(self):
        if self.current_term < self.num_terms:
            result = self.a
            self.a, self.b = self.b, self.a + self.b
            self.current_term += 1
            return result
        else:
            raise StopIteration
fibonacci_iter = FibonacciIterator(10)
for num in fibonacci_iter:
    print(num)

# %%
#Q6.Write a generator function in Python that yields the powers of 2 up to a given exponent?
#Ans:
def power_of_two(exponent):
  for i in range(exponent+1):
    yield 2**i
for power in power_of_two(5):
  print(power)

# %%
#Q8.Use a lambda function in Python to sort a list of tuples based on the second element of each tuple?
#Ans:
# Sample list of tuples
data = [(1, 5), (3, 2), (4, 8), (2, 1)]

# Sorting based on the second element of each tuple
sorted_data = sorted(data, key=lambda x: x[1])

# Print the sorted list
print(sorted_data)

# %%
#Q9. Write a Python program that uses `map()` to convert a list of temperatures from Celsius to Fahrenheit?
#Ans:
def celcius_to_fahreheit(celcius):
  return (celcius * 9/5) + 32
celcius_temps = [0,10,20,30,40]
fahrenheit_temps = list(map(celcius_to_fahreheit,celcius_temps))
print(fahrenheit_temps)

# %%
#Q10. Create a Python program that uses `filter()` to remove all the vowels from a given string?
#Ans:
def filter_vowel(self):
  vowels = "aeiouAEIOU"
  result = "".join(filter(lambda char: char not in vowels, self))
  return result
my_string = "shubham verma"
without_vowels = filter_vowel(my_string)
print(without_vowels)

# %%
"""Q11.11) Imagine an accounting routine used in a book shop. It works on a list with sublists, which look like this:







Write a Python program, which returns a list with 2-tuples. Each tuple consists of the order number and the
product of the price per item and the quantity. The product should be increased by 10,- € if the value of the
order is smaller than 100,00 €.

Write a Python program using lambda and map"""
#Ans:
orders = [
    [34587, 'Learning Python, Mark Lutz', 4, 40.95],
    [98762, 'Programming Python, Mark Lutz', 5, 56.80],
    [77226, 'Head First Python, Paul Barry', 3, 32.95],
    [88112, 'Einführung in Python3, Bernd Klein', 3, 24.99]
]

invoice_totals = list(map(
    lambda order: (order[0], order[2] * order[3] if order[2] * order[3] >= 100 else order[2] * order[3] + 10),
    orders
))

print(invoice_totals)
